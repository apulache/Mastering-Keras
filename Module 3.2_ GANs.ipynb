# %% [markdown]
# ##GANs for Synthetic Data Generation
#
# We implement a Generative Adversarial Network (GAN) in the Keras functional API. In this module we will pay attention to:
#
# - Implementing the GAN architecture in Keras.
# - Training our model.
# - Using our model to generate synthetic data.
#
# Note that we will not spend time tuning hyper-parameters: The purpose is to show how different techniques can be implemented in Keras, not to solve particular data science problems as optimally as possible. Obviously, most techniques include hyper-parameters that need to be tuned for optimal performance.

# %% [markdown]
# We import required libraries.

# %%
from keras.datasets.mnist import load_data
from keras import Model
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Input,Dense,Conv2D,Flatten,Dropout,LeakyReLU,Reshape,Conv2DTranspose
from keras.utils.vis_utils import model_to_dot

from matplotlib import pyplot

import numpy as np
import numpy.random as rng

# %% [markdown]
# As in the denoising auto-encoder module, we will be working with the MNIST data. These are 28x28 greyscale images of handwritten digits (0-9). The classes are the digit.
#
# This data is included in Keras.datasets library, so it is easy to load. We will expand the image dimension so that we have a single channel (as it is greyscale we have only one channel), and normalize the pixel values to real numbers between 0 and 1.
#
# We will only work with the training data, and so will create a function that pre-processes and returns that. If you want to look at the data, examine the code in module 2.4, as this provides functions for viewing the MNIST images with their class labels.

# %%
def get_data ():
  # load the images into memory
  (trainX, trainy), (testX, testy) = load_data()
  # We will only really work with the trainX data.
  # Let's expand it to add channel dimension
  X = np.expand_dims(trainX, axis=-1)
  # Convert from unsigned ints to floats and scale to between 0 and 1.
  X = X.astype('float32')
  X = X / 255.0
  return X

# %% [markdown]
# We call our get data function.

# %%
X=get_data()

# %% [markdown]
# We want our discriminator to train on batches of real and fake images, learning to distinguish between the two. So we need a function to grab a set of real images from our MNIST image data.

# %%
# select real samples
def select_real_images(dataset, n_samples):
    # choose random instances
    indices = rng.randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[indices]
    # generate 'real' class labels (1)
    y = np.ones((n_samples, 1))
    return X, y

# %% [markdown]
# Now let us define a function to create our discriminator model. We will also compile it within the function, so if you want to play around with the optimizer change the code in here.

# %%
def get_discriminator(in_shape=(28,28,1)):
  # Define Model
  # This is a basic binary classification CNN
  inputs=Input(in_shape)
  
  conv1=Conv2D(64, (3,3), strides=(2, 2), padding='same')(inputs)
  leak1=LeakyReLU(alpha=.2)(conv1)
  drop1=Dropout(.4)(leak1)
  
  conv2=Conv2D(64, (3,3), strides=(2, 2), padding='same')(drop1)
  leak2=LeakyReLU(alpha=.2)(conv2)
  drop2=Dropout(.4)(leak2)
  
  flat=Flatten()(drop2)
  outputs=Dense(1,activation='sigmoid')(flat)
  
  # Create Model
  model=Model(inputs=inputs,outputs=outputs)
  
  # Compile model
  opt = Adam(lr=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

# %% [markdown]
# If you wish, run the following code block to create an instance of the discriminator model in order to view a summary.
#
# Note we will create the discriminator instance we use for the problem in a later code block.

# %%
# Get the discriminator
discriminator = get_discriminator()
# View a summary of the discriminator
discriminator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 64)        640
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 3137
# =================================================================
# Total params: 40,705
# Trainable params: 40,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_generator(noise_dim=100):
    # Define the generator model
    inputs=Input((noise_dim,))
    
    # Create a basis for 7x7 image
    # We are using the noise to generate 128 high level 'feature maps' in a 7x7 space
    n = 128 * 7 * 7
    dense = Dense(n)(inputs)
    leak1 = LeakyReLU(alpha=0.2)(dense)
    reshape = Reshape((7, 7, 128))(leak1)
    
    # Now we extract lower level features...
    # Upsample to 14x14
    conv_tran1 = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(reshape)
    leak2=LeakyReLU(alpha=0.2)(conv_tran1)
    
    # Now we extract even lower level features...
    # Upsample to 28x28
    conv_tran2 = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(leak2)
    leak3 = LeakyReLU(alpha=0.2)(conv_tran2)
    
    # Finally we put togeather our pixel values for the synthetic image
    outputs = Conv2D(1, (7,7), activation='sigmoid', padding='same')(leak3)
    
    # Create the model and return it
    model=Model(inputs=inputs,outputs=outputs)
    return model

# %% [markdown]
# If you wish, run the following code block to create an instance of the generator model in order to view a summary. You can change the dimension of the noise vector if you like.
#
# Note we will create the generator instance we use for the problem in a later code block.

# %%
# Specify the dimension of the noise vector
noise_dim = 100
# Get the generator model
generator = get_generator(noise_dim)
# Summarize the model
generator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 6272)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 128)       262272
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 1)         6273
# =================================================================
# Total params: 1,164,289
# Trainable params: 1,164,289
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Obviously we want to generate this noise from something simple so that we can sample from the same distribution later. So we use simple independent Gaussian noise.
#
# We create a function that will generate as many of these noise vectors as we wish.

# %%
# Generate independent Gaussian noise as input for the generator
def generate_input_noise(noise_dim, num_vectors):
    # Generate independent Gaussian noise
    noise_input = rng.standard_normal(noise_dim * num_vectors)
    # Reshape into a 2d array
    noise_input = noise_input.reshape(num_vectors, noise_dim)
    return noise_input

# %% [markdown]
# Now we create a function to generate fake images from the noise vectors using the generator. We will also get this function to return labels indicating that the images are fake (we represent this by 0).

# %%
# Generate n fake images using the generator
def generate_fake_images(generator, noise_dim, n_images):
    # Generate noise vectors
    noise = generate_input_noise(noise_dim, n_images)
    # Use generator to create fake images from noise vectors
    fakes = generator.predict(noise)
    # create 'fake' class labels (0)
    labels = np.zeros((n_images, 1))
    return fakes, labels

# %% [markdown]
# Let's also create a function that plot's fake images created by the generator so we look at them.

# %%
# Plot fake images created by generator from random noise
def plot_generated_images(generator,noise_dim=100,n_images=25):
    # Create the fake images (we don't need the labels here)
    X, _ = generate_fake_images(generator, noise_dim, n_images)
    # Plot the fake images
    for i in range(n_images):
        pyplot.subplot(5, 5, 1 + i)
        pyplot.axis('off')
        pyplot.imshow(X[i, :, :, 0], cmap='gray_r')
    pyplot.show()

# %% [markdown]
# Now we will create a function to make our GAN. This will involve putting the discriminator and generator together into a single model. We will also want to be able to treat them as individual models as well, so we will return (1) the discriminator, (2) the generator, and (3) the combined GAN.
#
# Note that we will make the weights in the discriminator non-trainable in the combined GAN model. This means that when we train the GAN we are actually only optimizing the weights in the generator. I discuss this further after we define the train function below.
#
# Once again, we will compile the model in the function. This is the optimizer that will be used for training the generator (because of the above). If you want to play around with the optimizer change the code inside the function.

# %%
# Create the discriminator, generator and GAN networks.
# Compile networks requiring compilation within function.
def get_gan_models(noise_dim=100):
    # Create the discriminator (compiled internally)
    discriminator = get_discriminator()
    # Create the generator
    generator = get_generator(noise_dim)
    
    # Make weights in the discriminator not trainable
    discriminator.trainable = False
    
    # Make GAN
    inputs = Input((noise_dim,))
    gan = Model(inputs,discriminator(generator(inputs)))
    
    # Compile model
    opt = Adam(lr=0.0002, beta_1=0.5)
    gan.compile(loss='binary_crossentropy', optimizer=opt)
    
    return discriminator,generator,gan

# %% [markdown]
# Now let's finally get our networks. If you want to change the noise dimension we work with in the problem, change the value here.

# %%
noise_dim=100
discriminator,generator,gan=get_gan_models(noise_dim)

# %% [markdown]
# We are going to code a manual implementation of the training loop. This is so we can implement appropriate training for the discriminater and generator.
#
# Note we do not use validation data, and such data makes little sense in this context.

# %%
# Train the generator and discriminator
def train(
    gan, 
    generator,
    discriminator,
    dataset, 
    noise_dim=100, 
    epochs=100, 
    batch_size=256
):
    # We keep the amount of work done per 'epoch' matching
    # the dataset size, though in reality this is quite arbitrary.
    batches_per_epoch = int(dataset.shape[0] / batch_size)
    half_batch = int(batch_size / 2)
    # Iterate through desired number of epochs
    for i in range(epochs):
        # Iterate through batches 
        for j in range(batches_per_epoch):
            # Train the discriminator            
            # Get randomly selected real images
            X_real, Y_real = select_real_images(dataset, half_batch)
            # Generate fake images
            X_fake, Y_fake = generate_fake_images(generator, noise_dim, half_batch)
            # Create training set for the discriminator
            X, Y = np.vstack((X_real, X_fake)), np.vstack((Y_real, Y_fake))
            # Update discriminator model weights
            d_loss, _ = discriminator.train_on_batch(X, Y)
            
            # Train the generator
            # Prepare input noise
            X_gan = generate_input_noise(noise_dim, batch_size)
            # Create inverted labels for the fake samples
            # This is because the GAN/generator is trying to get the discriminator
            # to classify these fake images as real.
            Y_gan = np.ones((batch_size, 1))
            # Update the generator weights via the discriminator's error
            # Remember the discriminator's weights are fixed in the GAN,
            # so these will not be adjusted.
            g_loss = gan.train_on_batch(X_gan, Y_gan)
            
            # Give information about loss on this batch
            print("Epoch: {} Batch: {}/{} Disc. Loss: {:06.5f} Gen. Loss: {:06.5f}".format(i+1, j+1,batches_per_epoch, d_loss, g_loss))

# %% [markdown]
# Making the discriminator not trainable is a clever trick in the Keras API.
#
# The trainable property impacts the model after it is compiled. The discriminator model was compiled with trainable layers, therefore the model weights in those layers will be updated when the standalone model is updated via calls to the train_on_batch() function.
#
# The discriminator model was then marked as not trainable, added to the GAN model, and compiled. In this model, the model weights of the discriminator model are not trainable and cannot be changed when the GAN model is updated via calls to the train_on_batch() function. This change in the trainable property does not impact the training of standalone discriminator model.
#
# This behavior is described in the Keras API documentation here:
#
# [How can I “freeze” Keras layers?](https://keras.io/getting-started/faq/#how-can-i-freeze-keras-layers)

# %%
train(gan,generator,discriminator,X)
# Out:
#  Loss: 0.68627 Gen. Loss: 0.70007
# Epoch: 99 Batch: 159/234 Disc. Loss: 0.69044 Gen. Loss: 0.69495
# Epoch: 99 Batch: 160/234 Disc. Loss: 0.69223 Gen. Loss: 0.71723
# Epoch: 99 Batch: 161/234 Disc. Loss: 0.69440 Gen. Loss: 0.71724
# Epoch: 99 Batch: 162/234 Disc. Loss: 0.69418 Gen. Loss: 0.70178
# Epoch: 99 Batch: 163/234 Disc. Loss: 0.68924 Gen. Loss: 0.69261
# Epoch: 99 Batch: 164/234 Disc. Loss: 0.68967 Gen. Loss: 0.70777
# Epoch: 99 Batch: 165/234 Disc. Loss: 0.68587 Gen. Loss: 0.69715
# Epoch: 99 Batch: 166/234 Disc. Loss: 0.69620 Gen. Loss: 0.68352
# Epoch: 99 Batch: 167/234 Disc. Loss: 0.69032 Gen. Loss: 0.68575
# Epoch: 99 Batch: 168/234 Disc. Loss: 0.69327 Gen. Loss: 0.69075
# Epoch: 99 Batch: 169/234 Disc. Loss: 0.68507 Gen. Loss: 0.70429
# Epoch: 99 Batch: 170/234 Disc. Loss: 0.68970 Gen. Loss: 0.68958
# Epoch: 99 Batch: 171/234 Disc. Loss: 0.68780 Gen. Loss: 0.70268
# Epoch: 99 Batch: 172/234 Disc. Loss: 0.69082 Gen. Loss: 0.69992
# Epoch: 99 Batch: 173/234 Disc. Loss: 0.69297 Gen. Loss: 0.70075
# Epoch: 99 Batch: 174/234 Disc. Loss: 0.69236 Gen. Loss: 0.70093
# Epoch: 99 Batch: 175/234 Disc. Loss: 0.69222 Gen. Loss: 0.69383
# Epoch: 99 Batch: 176/234 Disc. Loss: 0.68852 Gen. Loss: 0.72261
# Epoch: 99 Batch: 177/234 Disc. Loss: 0.68973 Gen. Loss: 0.71268
# Epoch: 99 Batch: 178/234 Disc. Loss: 0.69856 Gen. Loss: 0.71904
# Epoch: 99 Batch: 179/234 Disc. Loss: 0.68331 Gen. Loss: 0.70372
# Epoch: 99 Batch: 180/234 Disc. Loss: 0.69290 Gen. Loss: 0.68528
# Epoch: 99 Batch: 181/234 Disc. Loss: 0.68945 Gen. Loss: 0.67704
# Epoch: 99 Batch: 182/234 Disc. Loss: 0.68763 Gen. Loss: 0.66609
# Epoch: 99 Batch: 183/234 Disc. Loss: 0.70264 Gen. Loss: 0.69684
# Epoch: 99 Batch: 184/234 Disc. Loss: 0.69123 Gen. Loss: 0.74184
# Epoch: 99 Batch: 185/234 Disc. Loss: 0.68755 Gen. Loss: 0.74042
# Epoch: 99 Batch: 186/234 Disc. Loss: 0.68193 Gen. Loss: 0.71092
# Epoch: 99 Batch: 187/234 Disc. Loss: 0.68767 Gen. Loss: 0.68088
# Epoch: 99 Batch: 188/234 Disc. Loss: 0.68903 Gen. Loss: 0.66196
# Epoch: 99 Batch: 189/234 Disc. Loss: 0.69428 Gen. Loss: 0.67567
# Epoch: 99 Batch: 190/234 Disc. Loss: 0.69004 Gen. Loss: 0.70831
# Epoch: 99 Batch: 191/234 Disc. Loss: 0.68946 Gen. Loss: 0.73025
# Epoch: 99 Batch: 192/234 Disc. Loss: 0.69111 Gen. Loss: 0.73781
# Epoch: 99 Batch: 193/234 Disc. Loss: 0.69032 Gen. Loss: 0.71037
# Epoch: 99 Batch: 194/234 Disc. Loss: 0.68942 Gen. Loss: 0.69177
# Epoch: 99 Batch: 195/234 Disc. Loss: 0.68995 Gen. Loss: 0.69776
# Epoch: 99 Batch: 196/234 Disc. Loss: 0.69440 Gen. Loss: 0.69672
# Epoch: 99 Batch: 197/234 Disc. Loss: 0.68869 Gen. Loss: 0.70124
# Epoch: 99 Batch: 198/234 Disc. Loss: 0.68898 Gen. Loss: 0.69938
# Epoch: 99 Batch: 199/234 Disc. Loss: 0.68989 Gen. Loss: 0.68640
# Epoch: 99 Batch: 200/234 Disc. Loss: 0.68170 Gen. Loss: 0.68085
# Epoch: 99 Batch: 201/234 Disc. Loss: 0.68945 Gen. Loss: 0.69351
# Epoch: 99 Batch: 202/234 Disc. Loss: 0.68681 Gen. Loss: 0.69331
# Epoch: 99 Batch: 203/234 Disc. Loss: 0.68777 Gen. Loss: 0.69617
# Epoch: 99 Batch: 204/234 Disc. Loss: 0.68539 Gen. Loss: 0.71150
# Epoch: 99 Batch: 205/234 Disc. Loss: 0.69560 Gen. Loss: 0.70878
# Epoch: 99 Batch: 206/234 Disc. Loss: 0.69456 Gen. Loss: 0.69907
# Epoch: 99 Batch: 207/234 Disc. Loss: 0.69108 Gen. Loss: 0.71025
# Epoch: 99 Batch: 208/234 Disc. Loss: 0.68899 Gen. Loss: 0.69449
# Epoch: 99 Batch: 209/234 Disc. Loss: 0.69974 Gen. Loss: 0.69572
# Epoch: 99 Batch: 210/234 Disc. Loss: 0.69492 Gen. Loss: 0.69637
# Epoch: 99 Batch: 211/234 Disc. Loss: 0.69332 Gen. Loss: 0.71317
# Epoch: 99 Batch: 212/234 Disc. Loss: 0.69103 Gen. Loss: 0.71578
# Epoch: 99 Batch: 213/234 Disc. Loss: 0.68829 Gen. Loss: 0.71251
# Epoch: 99 Batch: 214/234 Disc. Loss: 0.69125 Gen. Loss: 0.70645
# Epoch: 99 Batch: 215/234 Disc. Loss: 0.68065 Gen. Loss: 0.70585
# Epoch: 99 Batch: 216/234 Disc. Loss: 0.70040 Gen. Loss: 0.67861
# Epoch: 99 Batch: 217/234 Disc. Loss: 0.69103 Gen. Loss: 0.69851
# Epoch: 99 Batch: 218/234 Disc. Loss: 0.69059 Gen. Loss: 0.70878
# Epoch: 99 Batch: 219/234 Disc. Loss: 0.69256 Gen. Loss: 0.71396
# Epoch: 99 Batch: 220/234 Disc. Loss: 0.69378 Gen. Loss: 0.70500
# Epoch: 99 Batch: 221/234 Disc. Loss: 0.68694 Gen. Loss: 0.69466
# Epoch: 99 Batch: 222/234 Disc. Loss: 0.68378 Gen. Loss: 0.67419
# Epoch: 99 Batch: 223/234 Disc. Loss: 0.69240 Gen. Loss: 0.67455
# Epoch: 99 Batch: 224/234 Disc. Loss: 0.68950 Gen. Loss: 0.69664
# Epoch: 99 Batch: 225/234 Disc. Loss: 0.68623 Gen. Loss: 0.71281
# Epoch: 99 Batch: 226/234 Disc. Loss: 0.69123 Gen. Loss: 0.72183
# Epoch: 99 Batch: 227/234 Disc. Loss: 0.69515 Gen. Loss: 0.72664
# Epoch: 99 Batch: 228/234 Disc. Loss: 0.68947 Gen. Loss: 0.70913
# Epoch: 99 Batch: 229/234 Disc. Loss: 0.69672 Gen. Loss: 0.70237
# Epoch: 99 Batch: 230/234 Disc. Loss: 0.69528 Gen. Loss: 0.71013
# Epoch: 99 Batch: 231/234 Disc. Loss: 0.68375 Gen. Loss: 0.71450
# Epoch: 99 Batch: 232/234 Disc. Loss: 0.68460 Gen. Loss: 0.70667
# Epoch: 99 Batch: 233/234 Disc. Loss: 0.69095 Gen. Loss: 0.69910
# Epoch: 99 Batch: 234/234 Disc. Loss: 0.69207 Gen. Loss: 0.69882
# Epoch: 100 Batch: 1/234 Disc. Loss: 0.68676 Gen. Loss: 0.69749
# Epoch: 100 Batch: 2/234 Disc. Loss: 0.68385 Gen. Loss: 0.69686
# Epoch: 100 Batch: 3/234 Disc. Loss: 0.69474 Gen. Loss: 0.71018
# Epoch: 100 Batch: 4/234 Disc. Loss: 0.68642 Gen. Loss: 0.69901
# Epoch: 100 Batch: 5/234 Disc. Loss: 0.68870 Gen. Loss: 0.70529
# Epoch: 100 Batch: 6/234 Disc. Loss: 0.69337 Gen. Loss: 0.71120
# Epoch: 100 Batch: 7/234 Disc. Loss: 0.69597 Gen. Loss: 0.69196
# Epoch: 100 Batch: 8/234 Disc. Loss: 0.69826 Gen. Loss: 0.67461
# Epoch: 100 Batch: 9/234 Disc. Loss: 0.69762 Gen. Loss: 0.69122
# Epoch: 100 Batch: 10/234 Disc. Loss: 0.68694 Gen. Loss: 0.71216
# Epoch: 100 Batch: 11/234 Disc. Loss: 0.68761 Gen. Loss: 0.72189
# Epoch: 100 Batch: 12/234 Disc. Loss: 0.69400 Gen. Loss: 0.71971
# Epoch: 100 Batch: 13/234 Disc. Loss: 0.69628 Gen. Loss: 0.69018
# Epoch: 100 Batch: 14/234 Disc. Loss: 0.69660 Gen. Loss: 0.69455
# Epoch: 100 Batch: 15/234 Disc. Loss: 0.69436 Gen. Loss: 0.70127
# Epoch: 100 Batch: 16/234 Disc. Loss: 0.69198 Gen. Loss: 0.70929
# Epoch: 100 Batch: 17/234 Disc. Loss: 0.69231 Gen. Loss: 0.71441
# Epoch: 100 Batch: 18/234 Disc. Loss: 0.69057 Gen. Loss: 0.70057
# Epoch: 100 Batch: 19/234 Disc. Loss: 0.69897 Gen. Loss: 0.68674
# Epoch: 100 Batch: 20/234 Disc. Loss: 0.68518 Gen. Loss: 0.69816
# Epoch: 100 Batch: 21/234 Disc. Loss: 0.68609 Gen. Loss: 0.68650
# Epoch: 100 Batch: 22/234 Disc. Loss: 0.68346 Gen. Loss: 0.69704
# Epoch: 100 Batch: 23/234 Disc. Loss: 0.69236 Gen. Loss: 0.70531
# Epoch: 100 Batch: 24/234 Disc. Loss: 0.69716 Gen. Loss: 0.70775
# Epoch: 100 Batch: 25/234 Disc. Loss: 0.69304 Gen. Loss: 0.69706
# Epoch: 100 Batch: 26/234 Disc. Loss: 0.68936 Gen. Loss: 0.69723
# Epoch: 100 Batch: 27/234 Disc. Loss: 0.69411 Gen. Loss: 0.70310
# Epoch: 100 Batch: 28/234 Disc. Loss: 0.69002 Gen. Loss: 0.69756
# Epoch: 100 Batch: 29/234 Disc. Loss: 0.67864 Gen. Loss: 0.69955
# Epoch: 100 Batch: 30/234 Disc. Loss: 0.69145 Gen. Loss: 0.70568
# Epoch: 100 Batch: 31/234 Disc. Loss: 0.68325 Gen. Loss: 0.72176
# Epoch: 100 Batch: 32/234 Disc. Loss: 0.70196 Gen. Loss: 0.71070
# Epoch: 100 Batch: 33/234 Disc. Loss: 0.69185 Gen. Loss: 0.68576
# Epoch: 100 Batch: 34/234 Disc. Loss: 0.68396 Gen. Loss: 0.67663
# Epoch: 100 Batch: 35/234 Disc. Loss: 0.68116 Gen. Loss: 0.70696
# Epoch: 100 Batch: 36/234 Disc. Loss: 0.68802 Gen. Loss: 0.71068
# Epoch: 100 Batch: 37/234 Disc. Loss: 0.69350 Gen. Loss: 0.69748
# Epoch: 100 Batch: 38/234 Disc. Loss: 0.69717 Gen. Loss: 0.70338
# Epoch: 100 Batch: 39/234 Disc. Loss: 0.69652 Gen. Loss: 0.72215
# Epoch: 100 Batch: 40/234 Disc. Loss: 0.69247 Gen. Loss: 0.69199
# Epoch: 100 Batch: 41/234 Disc. Loss: 0.67998 Gen. Loss: 0.67134
# Epoch: 100 Batch: 42/234 Disc. Loss: 0.68675 Gen. Loss: 0.68808
# Epoch: 100 Batch: 43/234 Disc. Loss: 0.69551 Gen. Loss: 0.70703
# Epoch: 100 Batch: 44/234 Disc. Loss: 0.69723 Gen. Loss: 0.71593
# Epoch: 100 Batch: 45/234 Disc. Loss: 0.69638 Gen. Loss: 0.70670
# Epoch: 100 Batch: 46/234 Disc. Loss: 0.69225 Gen. Loss: 0.69920
# Epoch: 100 Batch: 47/234 Disc. Loss: 0.69432 Gen. Loss: 0.70594
# Epoch: 100 Batch: 48/234 Disc. Loss: 0.69626 Gen. Loss: 0.71931
# Epoch: 100 Batch: 49/234 Disc. Loss: 0.68647 Gen. Loss: 0.71082
# Epoch: 100 Batch: 50/234 Disc. Loss: 0.68851 Gen. Loss: 0.68283
# Epoch: 100 Batch: 51/234 Disc. Loss: 0.69226 Gen. Loss: 0.69519
# Epoch: 100 Batch: 52/234 Disc. Loss: 0.69843 Gen. Loss: 0.70198
# Epoch: 100 Batch: 53/234 Disc. Loss: 0.68982 Gen. Loss: 0.71280
# Epoch: 100 Batch: 54/234 Disc. Loss: 0.68976 Gen. Loss: 0.70205
# Epoch: 100 Batch: 55/234 Disc. Loss: 0.68417 Gen. Loss: 0.69106
# Epoch: 100 Batch: 56/234 Disc. Loss: 0.68726 Gen. Loss: 0.69019
# Epoch: 100 Batch: 57/234 Disc. Loss: 0.70009 Gen. Loss: 0.70432
# Epoch: 100 Batch: 58/234 Disc. Loss: 0.69280 Gen. Loss: 0.70379
# Epoch: 100 Batch: 59/234 Disc. Loss: 0.69062 Gen. Loss: 0.68576
# Epoch: 100 Batch: 60/234 Disc. Loss: 0.68674 Gen. Loss: 0.70892
# Epoch: 100 Batch: 61/234 Disc. Loss: 0.69698 Gen. Loss: 0.71851
# Epoch: 100 Batch: 62/234 Disc. Loss: 0.69914 Gen. Loss: 0.70781
# Epoch: 100 Batch: 63/234 Disc. Loss: 0.68415 Gen. Loss: 0.68979
# Epoch: 100 Batch: 64/234 Disc. Loss: 0.68440 Gen. Loss: 0.68560
# Epoch: 100 Batch: 65/234 Disc. Loss: 0.69291 Gen. Loss: 0.69516
# Epoch: 100 Batch: 66/234 Disc. Loss: 0.69986 Gen. Loss: 0.69526
# Epoch: 100 Batch: 67/234 Disc. Loss: 0.69031 Gen. Loss: 0.69747
# Epoch: 100 Batch: 68/234 Disc. Loss: 0.68965 Gen. Loss: 0.70646
# Epoch: 100 Batch: 69/234 Disc. Loss: 0.69233 Gen. Loss: 0.70694
# Epoch: 100 Batch: 70/234 Disc. Loss: 0.68575 Gen. Loss: 0.70868
# Epoch: 100 Batch: 71/234 Disc. Loss: 0.68995 Gen. Loss: 0.70887
# Epoch: 100 Batch: 72/234 Disc. Loss: 0.69655 Gen. Loss: 0.70558
# Epoch: 100 Batch: 73/234 Disc. Loss: 0.69007 Gen. Loss: 0.70886
# Epoch: 100 Batch: 74/234 Disc. Loss: 0.69439 Gen. Loss: 0.69750
# Epoch: 100 Batch: 75/234 Disc. Loss: 0.69143 Gen. Loss: 0.68509
# Epoch: 100 Batch: 76/234 Disc. Loss: 0.69116 Gen. Loss: 0.69511
# Epoch: 100 Batch: 77/234 Disc. Loss: 0.69896 Gen. Loss: 0.69826
# Epoch: 100 Batch: 78/234 Disc. Loss: 0.68320 Gen. Loss: 0.70565
# Epoch: 100 Batch: 79/234 Disc. Loss: 0.68796 Gen. Loss: 0.71520
# Epoch: 100 Batch: 80/234 Disc. Loss: 0.68466 Gen. Loss: 0.71289
# Epoch: 100 Batch: 81/234 Disc. Loss: 0.69085 Gen. Loss: 0.71203
# Epoch: 100 Batch: 82/234 Disc. Loss: 0.68912 Gen. Loss: 0.70093
# Epoch: 100 Batch: 83/234 Disc. Loss: 0.69076 Gen. Loss: 0.69515
# Epoch: 100 Batch: 84/234 Disc. Loss: 0.68729 Gen. Loss: 0.67884
# Epoch: 100 Batch: 85/234 Disc. Loss: 0.68888 Gen. Loss: 0.69020
# Epoch: 100 Batch: 86/234 Disc. Loss: 0.68657 Gen. Loss: 0.70521
# Epoch: 100 Batch: 87/234 Disc. Loss: 0.68827 Gen. Loss: 0.70307
# Epoch: 100 Batch: 88/234 Disc. Loss: 0.69065 Gen. Loss: 0.69572
# Epoch: 100 Batch: 89/234 Disc. Loss: 0.68308 Gen. Loss: 0.68880
# Epoch: 100 Batch: 90/234 Disc. Loss: 0.69420 Gen. Loss: 0.70807
# Epoch: 100 Batch: 91/234 Disc. Loss: 0.68595 Gen. Loss: 0.69830
# Epoch: 100 Batch: 92/234 Disc. Loss: 0.68611 Gen. Loss: 0.70707
# Epoch: 100 Batch: 93/234 Disc. Loss: 0.69575 Gen. Loss: 0.71209
# Epoch: 100 Batch: 94/234 Disc. Loss: 0.69988 Gen. Loss: 0.70072
# Epoch: 100 Batch: 95/234 Disc. Loss: 0.69499 Gen. Loss: 0.66695
# Epoch: 100 Batch: 96/234 Disc. Loss: 0.68475 Gen. Loss: 0.67163
# Epoch: 100 Batch: 97/234 Disc. Loss: 0.69952 Gen. Loss: 0.69266
# Epoch: 100 Batch: 98/234 Disc. Loss: 0.68807 Gen. Loss: 0.72888
# Epoch: 100 Batch: 99/234 Disc. Loss: 0.68725 Gen. Loss: 0.72908
# Epoch: 100 Batch: 100/234 Disc. Loss: 0.68551 Gen. Loss: 0.70005
# Epoch: 100 Batch: 101/234 Disc. Loss: 0.69291 Gen. Loss: 0.68772
# Epoch: 100 Batch: 102/234 Disc. Loss: 0.68552 Gen. Loss: 0.67586
# Epoch: 100 Batch: 103/234 Disc. Loss: 0.68899 Gen. Loss: 0.70517
# Epoch: 100 Batch: 104/234 Disc. Loss: 0.68901 Gen. Loss: 0.70675
# Epoch: 100 Batch: 105/234 Disc. Loss: 0.69250 Gen. Loss: 0.69569
# Epoch: 100 Batch: 106/234 Disc. Loss: 0.69858 Gen. Loss: 0.69370
# Epoch: 100 Batch: 107/234 Disc. Loss: 0.68548 Gen. Loss: 0.70385
# Epoch: 100 Batch: 108/234 Disc. Loss: 0.69582 Gen. Loss: 0.70015
# Epoch: 100 Batch: 109/234 Disc. Loss: 0.69103 Gen. Loss: 0.71205
# Epoch: 100 Batch: 110/234 Disc. Loss: 0.69528 Gen. Loss: 0.70254
# Epoch: 100 Batch: 111/234 Disc. Loss: 0.70159 Gen. Loss: 0.68580
# Epoch: 100 Batch: 112/234 Disc. Loss: 0.69050 Gen. Loss: 0.69360
# Epoch: 100 Batch: 113/234 Disc. Loss: 0.69045 Gen. Loss: 0.69258
# Epoch: 100 Batch: 114/234 Disc. Loss: 0.69074 Gen. Loss: 0.69738
# Epoch: 100 Batch: 115/234 Disc. Loss: 0.68922 Gen. Loss: 0.69908
# Epoch: 100 Batch: 116/234 Disc. Loss: 0.69239 Gen. Loss: 0.69364
# Epoch: 100 Batch: 117/234 Disc. Loss: 0.68672 Gen. Loss: 0.69458
# Epoch: 100 Batch: 118/234 Disc. Loss: 0.69007 Gen. Loss: 0.69817
# Epoch: 100 Batch: 119/234 Disc. Loss: 0.68954 Gen. Loss: 0.70675
# Epoch: 100 Batch: 120/234 Disc. Loss: 0.68175 Gen. Loss: 0.70950
# Epoch: 100 Batch: 121/234 Disc. Loss: 0.68490 Gen. Loss: 0.70146
# Epoch: 100 Batch: 122/234 Disc. Loss: 0.69736 Gen. Loss: 0.69977
# Epoch: 100 Batch: 123/234 Disc. Loss: 0.68537 Gen. Loss: 0.68898
# Epoch: 100 Batch: 124/234 Disc. Loss: 0.69179 Gen. Loss: 0.68502
# Epoch: 100 Batch: 125/234 Disc. Loss: 0.68272 Gen. Loss: 0.69166
# Epoch: 100 Batch: 126/234 Disc. Loss: 0.69166 Gen. Loss: 0.70424
# Epoch: 100 Batch: 127/234 Disc. Loss: 0.68819 Gen. Loss: 0.72154
# Epoch: 100 Batch: 128/234 Disc. Loss: 0.69151 Gen. Loss: 0.70326
# Epoch: 100 Batch: 129/234 Disc. Loss: 0.68655 Gen. Loss: 0.70556
# Epoch: 100 Batch: 130/234 Disc. Loss: 0.69285 Gen. Loss: 0.68925
# Epoch: 100 Batch: 131/234 Disc. Loss: 0.69204 Gen. Loss: 0.69118
# Epoch: 100 Batch: 132/234 Disc. Loss: 0.69009 Gen. Loss: 0.70736
# Epoch: 100 Batch: 133/234 Disc. Loss: 0.69105 Gen. Loss: 0.70576
# Epoch: 100 Batch: 134/234 Disc. Loss: 0.68726 Gen. Loss: 0.70728
# Epoch: 100 Batch: 135/234 Disc. Loss: 0.68757 Gen. Loss: 0.68824
# Epoch: 100 Batch: 136/234 Disc. Loss: 0.69460 Gen. Loss: 0.69928
# Epoch: 100 Batch: 137/234 Disc. Loss: 0.69098 Gen. Loss: 0.71130
# Epoch: 100 Batch: 138/234 Disc. Loss: 0.69147 Gen. Loss: 0.71076
# Epoch: 100 Batch: 139/234 Disc. Loss: 0.68750 Gen. Loss: 0.69497
# Epoch: 100 Batch: 140/234 Disc. Loss: 0.68916 Gen. Loss: 0.68800
# Epoch: 100 Batch: 141/234 Disc. Loss: 0.68601 Gen. Loss: 0.69115
# Epoch: 100 Batch: 142/234 Disc. Loss: 0.68983 Gen. Loss: 0.69827
# Epoch: 100 Batch: 143/234 Disc. Loss: 0.69164 Gen. Loss: 0.70560
# Epoch: 100 Batch: 144/234 Disc. Loss: 0.69197 Gen. Loss: 0.71419
# Epoch: 100 Batch: 145/234 Disc. Loss: 0.68841 Gen. Loss: 0.72306
# Epoch: 100 Batch: 146/234 Disc. Loss: 0.68612 Gen. Loss: 0.71598
# Epoch: 100 Batch: 147/234 Disc. Loss: 0.69427 Gen. Loss: 0.72030
# Epoch: 100 Batch: 148/234 Disc. Loss: 0.69061 Gen. Loss: 0.69903
# Epoch: 100 Batch: 149/234 Disc. Loss: 0.69013 Gen. Loss: 0.69042
# Epoch: 100 Batch: 150/234 Disc. Loss: 0.69265 Gen. Loss: 0.68412
# Epoch: 100 Batch: 151/234 Disc. Loss: 0.69025 Gen. Loss: 0.69835
# Epoch: 100 Batch: 152/234 Disc. Loss: 0.69253 Gen. Loss: 0.70172
# Epoch: 100 Batch: 153/234 Disc. Loss: 0.68821 Gen. Loss: 0.70824
# Epoch: 100 Batch: 154/234 Disc. Loss: 0.70048 Gen. Loss: 0.69801
# Epoch: 100 Batch: 155/234 Disc. Loss: 0.69402 Gen. Loss: 0.70051
# Epoch: 100 Batch: 156/234 Disc. Loss: 0.69850 Gen. Loss: 0.68923
# Epoch: 100 Batch: 157/234 Disc. Loss: 0.68925 Gen. Loss: 0.69376
# Epoch: 100 Batch: 158/234 Disc. Loss: 0.68802 Gen. Loss: 0.70910
# Epoch: 100 Batch: 159/234 Disc. Loss: 0.68739 Gen. Loss: 0.72557
# Epoch: 100 Batch: 160/234 Disc. Loss: 0.69515 Gen. Loss: 0.73440
# Epoch: 100 Batch: 161/234 Disc. Loss: 0.68433 Gen. Loss: 0.72377
# Epoch: 100 Batch: 162/234 Disc. Loss: 0.68660 Gen. Loss: 0.69099
# Epoch: 100 Batch: 163/234 Disc. Loss: 0.68906 Gen. Loss: 0.67599
# Epoch: 100 Batch: 164/234 Disc. Loss: 0.69296 Gen. Loss: 0.67177
# Epoch: 100 Batch: 165/234 Disc. Loss: 0.68728 Gen. Loss: 0.68760
# Epoch: 100 Batch: 166/234 Disc. Loss: 0.69255 Gen. Loss: 0.70590
# Epoch: 100 Batch: 167/234 Disc. Loss: 0.68022 Gen. Loss: 0.70216
# Epoch: 100 Batch: 168/234 Disc. Loss: 0.69229 Gen. Loss: 0.70929
# Epoch: 100 Batch: 169/234 Disc. Loss: 0.68798 Gen. Loss: 0.72919
# Epoch: 100 Batch: 170/234 Disc. Loss: 0.69013 Gen. Loss: 0.70686
# Epoch: 100 Batch: 171/234 Disc. Loss: 0.68791 Gen. Loss: 0.69325
# Epoch: 100 Batch: 172/234 Disc. Loss: 0.69249 Gen. Loss: 0.67665
# Epoch: 100 Batch: 173/234 Disc. Loss: 0.68490 Gen. Loss: 0.69676
# Epoch: 100 Batch: 174/234 Disc. Loss: 0.68636 Gen. Loss: 0.71658
# Epoch: 100 Batch: 175/234 Disc. Loss: 0.69499 Gen. Loss: 0.70462
# Epoch: 100 Batch: 176/234 Disc. Loss: 0.69564 Gen. Loss: 0.70093
# Epoch: 100 Batch: 177/234 Disc. Loss: 0.68965 Gen. Loss: 0.69327
# Epoch: 100 Batch: 178/234 Disc. Loss: 0.69090 Gen. Loss: 0.67740
# Epoch: 100 Batch: 179/234 Disc. Loss: 0.69103 Gen. Loss: 0.69107
# Epoch: 100 Batch: 180/234 Disc. Loss: 0.69357 Gen. Loss: 0.69763
# Epoch: 100 Batch: 181/234 Disc. Loss: 0.68654 Gen. Loss: 0.69961
# Epoch: 100 Batch: 182/234 Disc. Loss: 0.69024 Gen. Loss: 0.69215
# Epoch: 100 Batch: 183/234 Disc. Loss: 0.69455 Gen. Loss: 0.69594
# Epoch: 100 Batch: 184/234 Disc. Loss: 0.69248 Gen. Loss: 0.69990
# Epoch: 100 Batch: 185/234 Disc. Loss: 0.69111 Gen. Loss: 0.72141
# Epoch: 100 Batch: 186/234 Disc. Loss: 0.68943 Gen. Loss: 0.71410
# Epoch: 100 Batch: 187/234 Disc. Loss: 0.68745 Gen. Loss: 0.73149
# Epoch: 100 Batch: 188/234 Disc. Loss: 0.68683 Gen. Loss: 0.71717
# Epoch: 100 Batch: 189/234 Disc. Loss: 0.69784 Gen. Loss: 0.71022
# Epoch: 100 Batch: 190/234 Disc. Loss: 0.68962 Gen. Loss: 0.68447
# Epoch: 100 Batch: 191/234 Disc. Loss: 0.69092 Gen. Loss: 0.66124
# Epoch: 100 Batch: 192/234 Disc. Loss: 0.68714 Gen. Loss: 0.68002
# Epoch: 100 Batch: 193/234 Disc. Loss: 0.69126 Gen. Loss: 0.69813
# Epoch: 100 Batch: 194/234 Disc. Loss: 0.69389 Gen. Loss: 0.71872
# Epoch: 100 Batch: 195/234 Disc. Loss: 0.68902 Gen. Loss: 0.70219
# Epoch: 100 Batch: 196/234 Disc. Loss: 0.69204 Gen. Loss: 0.69630
# Epoch: 100 Batch: 197/234 Disc. Loss: 0.68312 Gen. Loss: 0.70815
# Epoch: 100 Batch: 198/234 Disc. Loss: 0.69137 Gen. Loss: 0.71443
# Epoch: 100 Batch: 199/234 Disc. Loss: 0.69569 Gen. Loss: 0.71473
# Epoch: 100 Batch: 200/234 Disc. Loss: 0.69219 Gen. Loss: 0.70837
# Epoch: 100 Batch: 201/234 Disc. Loss: 0.69113 Gen. Loss: 0.70448
# Epoch: 100 Batch: 202/234 Disc. Loss: 0.68121 Gen. Loss: 0.70500
# Epoch: 100 Batch: 203/234 Disc. Loss: 0.69845 Gen. Loss: 0.68304
# Epoch: 100 Batch: 204/234 Disc. Loss: 0.68478 Gen. Loss: 0.69213
# Epoch: 100 Batch: 205/234 Disc. Loss: 0.69174 Gen. Loss: 0.70334
# Epoch: 100 Batch: 206/234 Disc. Loss: 0.69612 Gen. Loss: 0.69256
# Epoch: 100 Batch: 207/234 Disc. Loss: 0.68956 Gen. Loss: 0.70291
# Epoch: 100 Batch: 208/234 Disc. Loss: 0.69171 Gen. Loss: 0.69075
# Epoch: 100 Batch: 209/234 Disc. Loss: 0.69151 Gen. Loss: 0.69932
# Epoch: 100 Batch: 210/234 Disc. Loss: 0.69263 Gen. Loss: 0.69653
# Epoch: 100 Batch: 211/234 Disc. Loss: 0.70008 Gen. Loss: 0.70082
# Epoch: 100 Batch: 212/234 Disc. Loss: 0.68717 Gen. Loss: 0.71107
# Epoch: 100 Batch: 213/234 Disc. Loss: 0.68542 Gen. Loss: 0.71022
# Epoch: 100 Batch: 214/234 Disc. Loss: 0.69113 Gen. Loss: 0.70540
# Epoch: 100 Batch: 215/234 Disc. Loss: 0.69028 Gen. Loss: 0.69232
# Epoch: 100 Batch: 216/234 Disc. Loss: 0.68875 Gen. Loss: 0.70162
# Epoch: 100 Batch: 217/234 Disc. Loss: 0.69598 Gen. Loss: 0.69567
# Epoch: 100 Batch: 218/234 Disc. Loss: 0.69230 Gen. Loss: 0.70032
# Epoch: 100 Batch: 219/234 Disc. Loss: 0.69520 Gen. Loss: 0.71278
# Epoch: 100 Batch: 220/234 Disc. Loss: 0.69667 Gen. Loss: 0.70172
# Epoch: 100 Batch: 221/234 Disc. Loss: 0.68123 Gen. Loss: 0.70450
# Epoch: 100 Batch: 222/234 Disc. Loss: 0.69203 Gen. Loss: 0.70550
# Epoch: 100 Batch: 223/234 Disc. Loss: 0.68461 Gen. Loss: 0.72201
# Epoch: 100 Batch: 224/234 Disc. Loss: 0.69232 Gen. Loss: 0.72928
# Epoch: 100 Batch: 225/234 Disc. Loss: 0.69782 Gen. Loss: 0.70397
# Epoch: 100 Batch: 226/234 Disc. Loss: 0.69063 Gen. Loss: 0.67747
# Epoch: 100 Batch: 227/234 Disc. Loss: 0.68135 Gen. Loss: 0.66897
# Epoch: 100 Batch: 228/234 Disc. Loss: 0.69155 Gen. Loss: 0.69502
# Epoch: 100 Batch: 229/234 Disc. Loss: 0.69015 Gen. Loss: 0.71894
# Epoch: 100 Batch: 230/234 Disc. Loss: 0.68665 Gen. Loss: 0.71197
# Epoch: 100 Batch: 231/234 Disc. Loss: 0.68324 Gen. Loss: 0.71287
# Epoch: 100 Batch: 232/234 Disc. Loss: 0.69593 Gen. Loss: 0.69071
# Epoch: 100 Batch: 233/234 Disc. Loss: 0.68898 Gen. Loss: 0.69762
# Epoch: 100 Batch: 234/234 Disc. Loss: 0.69350 Gen. Loss: 0.71497

# %% [markdown]
# You may see a warning:
#
# UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
#
# Don't worry about this - it is actually doing exactly what we want.
#
# When you set certain weights to trainable or untrainable (as we did in the line: discriminator.trainable = False) this only takes effect once you compile the model. We compiled the discriminator model before this call, so its weights are still trainable when we train *the discriminator model* by batch.
#
# But the discriminator model is also a *sub-model* of our complete GAN. And the GAN model was compiled *after* we set the discriminator weights to untrainable. So the discriminator weights will not be trained when we train the GAN model by batch. Neat huh?
#
# The warning is Keras thinking we have been too clever by half and are possibly making a mistake somewhere. But we aren't. :)
#
# You could get rid of the warning by setting the discriminator trainability to True and False and then recompiling models within the training loop. But that would be a lot more work...

# %%
plot_generated_images(generator,100,25)

# %% [markdown]
# 1. You might be surprised that there are images of all sorts of digits, thinking that it looks easiest for the generator to fake certain digits like '0'. But for any reasonably balanced multi-class problem, the generator cannot focus on simulating the simplest class - otherwise the discriminator will simply 'abandon' that class as typically fake.
#
# 2. You might be surprised that the loss functions oscillate. But remember the two networks are in competition!
#
# 3. We can generate synthetic data from the GAN. But unlike the variational auto-encoder, in this naive implementation we cannot generate synthetic data of certain classes (similar to known images).
